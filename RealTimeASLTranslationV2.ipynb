# %% [markdown]
# # Import Dependencies

# %%
import cv2
import os
import logging
import time
import numpy as np
import mediapipe as mp
import json
from tqdm import tqdm # for progress bars in Jupyter Notebook
from matplotlib import pyplot as plt

# %% [markdown]
# ## Detecting Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles

# %%
def setup_holistic_detection():
    # Initialize Camera Input
    cap = cv2.VideoCapture(0)

    # Set Up MediaPipe Holistic Model
    holistic = mp_holistic.Holistic(
        min_detection_confidence=0.5,
        min_tracking_confidence=0.5
    )

    return cap, holistic

# %%
def process_mp_frames(frame, holistic):
    # Opencv records in BGR while mediapipe supports RGB
    # We need to recolor frame to RGB to support MediaPipe processing
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False                  # Make Image non-writeable for performance
    results = holistic.process(image)              # process image and return object contain landmarks
    image.flags.writeable = True                   # Back to writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # Color back to BGR for OpenCV 

    return image, results

# %%
def draw_landmarks(image, results):
    # Draw face landmarks
    mp_drawing.draw_landmarks(image, 
                              results.face_landmarks, 
                              mp_holistic.FACEMESH_TESSELATION, # FACEMESH_CONTOURS could also be valid here
                              landmark_drawing_spec=mp_drawing.DrawingSpec(color=(170,86,0), thickness=1, circle_radius=2),
                              connection_drawing_spec=mp_drawing_styles.get_default_face_mesh_tesselation_style())
    # Draw pose connections
    mp_drawing.draw_landmarks(image, 
                              results.pose_landmarks, 
                              mp_holistic.POSE_CONNECTIONS,
                              landmark_drawing_spec=mp_drawing_styles.get_default_pose_landmarks_style())
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, 
                              results.left_hand_landmarks, 
                              mp_holistic.HAND_CONNECTIONS,
                              landmark_drawing_spec=mp_drawing_styles.get_default_hand_landmarks_style(), 
                              connection_drawing_spec=mp_drawing_styles.get_default_hand_connections_style())
    # Draw right hand connections
    mp_drawing.draw_landmarks(image, 
                              results.right_hand_landmarks, 
                              mp_holistic.HAND_CONNECTIONS,
                              landmark_drawing_spec=mp_drawing_styles.get_default_hand_landmarks_style(), 
                              connection_drawing_spec=mp_drawing_styles.get_default_hand_connections_style())

# %%
def extract_keypoints_comprehensive(results):
    # Pose Landmarks have 33 Keypoints
    # if results.pose_landmarks:
    #     pose_landmarks = []
    #     for res in results.pose_landmakrs.landmark:
    #         pose_landmarks.extend([res.x, res.y, res.z, res.visibility])
    #     pose = np.array(pose_landmarks)
    # else:
    #     pose = np.zeros(33*4)
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    keypoints_vector = np.concatenate([pose, face, lh, rh])
    # print(keypoints_vector)
    return keypoints_vector

# %%
def run_holistic_detection():
    os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Suppress TensorFlow loggin
    logging.getLogger('mediapipe').setLevel(logging.ERROR)  # Only show errors from mediapipe
    cap, holistic = setup_holistic_detection()

    while cap.isOpened():
        # Read frame
        ret, frame = cap.read()
        if not ret:
            print('camera stopped: no frames grabbed')
            break

        # Process Frame/Make dectections
        image, results = process_mp_frames(frame, holistic)
        # print(results)

        # Draw Landmarks
        draw_landmarks(image, results)

        # Extract Keypoints
        keypoints_vector = extract_keypoints_comprehensive(results)

        # Show to screen
        cv2.imshow('ASL Detection', image)

        # Exit on 'q' press
        if cv2.waitKey(10) & 0xFF == ord('q'):
            draw_landmarks(frame, results)
            plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
run_holistic_detection()

# %% [markdown]
# ## Dataset Collection Pipeline for Custom Camera Recordings

# %%
# Create Directories to store data
def create_directories(actions):
    DATA_PATH = os.path.join('MP_Data')

    # Detecting Actions
    for action in actions:
        # 30 is often considered minimum threshold to detect meaningful patterns
        # n >= 30 commonly used as rule of thumb
        for sequence in range(30): # 30 videos per action 
            try:
                os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
            except:
                pass

def collect_asl_data():
    # Define Actions - starting with a small set for testing
    actions = np.array(['hello', 'thanks', ' I love you', 'yes', 'no', 'please', 'sorry'])

    # create directories for data collection - 30 directories per action
    create_directories(actions)

    # Define data path
    DATA_PATH = os.path.join('MP_Data')

    # set up holistic model
    cap, holistic = setup_holistic_detection()

    # Loop through different actions
    for action in actions:
        # loop through sequences
        for sequence in range(30):
            # loop through video length of 30 frames
            for frame_num in range(30):
                # Read Feed
                ret, frame = cap.read()
                if not ret:
                    print('Failed to grab frame')
                    break

                # Process the frame for landmark detection
                image, results = process_mp_frames(frame, holistic)

                # Draw Landmarks on the image
                draw_landmarks(image, results)

                # Apply status text to the frame
                if frame_num == 0:
                    # Visual Countdown before starting each sequence
                    cv2.putText(image, 'STARTING COLLECTION', (120, 200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, f'Collecting for {action} - Sequence {sequence}', (15, 15), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
                    cv2.imshow('ASL Data Collection', image)
                    cv2.waitKey(2000)  # Wait 2 seconds before starting
                else:
                    # Display collection status
                    cv2.putText(image, f'Collecting for {action} - Sequence {sequence}', (15, 15), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
                    cv2.putText(image, f'Frame {frame_num}', (15, 30), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)

                # show to screen
                cv2.imshow('ASK Data Collection', image)

                # Export keypoints
                keypoints_vector = extract_keypoints_comprehensive(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints_vector)
                
                # Break gracefully on 'q' press
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    cap.release()
                    cv2.destroyAllWindows()
                    return
            
            # Short break between sequences
            if sequence < 29:  # Don't show after the last sequence
                # Display break message
                ret, frame = cap.read()
                if ret:
                    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
                    cv2.putText(image, 'SEQUENCE COMPLETE', (120, 200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Preparing for next sequence...', (120, 230), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1, cv2.LINE_AA)
                    cv2.imshow('ASL Data Collection', image)
                cv2.waitKey(2000)  # 2 second break
    
    # Release resources
    cap.release()
    cv2.destroyAllWindows()
    print("Data collection complete!")

# %%
collect_asl_data()

# %% [markdown]
# ## Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
DATA_PATH = os.path.join('MP_Data_01')
sequence_length = 30

# Automatically detect action classes from directory structure
actions = np.array([folder for folder in os.listdir(DATA_PATH) if not folder.startswith('.DS_Store')]) # .DS_Store is issue
print(f"Detected actions: {actions}")
# Out:
# Detected actions: ['please' 'no' 'thanks' 'hello' 'yes' 'iloveyou' 'sorry']

# %%
# Create label mapping
label_map = {label: num for num, label in enumerate(actions)}
print(f"Label mapping: {label_map}")
# Out:
# Label mapping: {'please': 0, 'no': 1, 'thanks': 2, 'hello': 3, 'yes': 4, 'iloveyou': 5, 'sorry': 6}

# %%
# Initialize empty lists for sequences and labels
sequences, labels = [], []

# Loop through each action
for action in actions:
    # Loop through all sequences
    sequence_folders = [folder for folder in os.listdir(os.path.join(DATA_PATH, action)) if not folder.startswith('.DS_Store')]
    for sequence in np.array(sequence_folders).astype(int):
        # Build window of frames for this sequence
        window = []
        for frame_num in range(sequence_length):
            # Load the frame data (keypoints)
            try:
                res = np.load(os.path.join(DATA_PATH, action, str(sequence), f"{frame_num}.npy"))
                window.append(res)
            except Exception as e:
                print(f"Error loading file: {os.path.join(DATA_PATH, action, str(sequence), f'{frame_num}.npy')}")
                print(f"Error details: {e}")
                # If a frame is missing, you can choose to skip or use zeros
                # Here we'll use zeros to maintain sequence length
                window.append(np.zeros(res.shape if 'res' in locals() else 1662))  # 1662 is the expected dimension based on your extraction function

        # Add this sequence and its label to our datasets - FOR WLASL -> may not have complete sequence
        if len(window) == sequence_length:  # Ensure we have a complete sequence
            sequences.append(window)
            labels.append(label_map[action])

# Convert sequences and labels to numpy arrays
X = np.array(sequences)
y = to_categorical(labels).astype(int)

print(f"Data shape: {X.shape}")  # Should be (num_sequences, sequence_length, num_features)
print(f"Labels shape: {y.shape}")  # Should be (num_sequences, num_classes)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=42)

print(f"Training data shape: {X_train.shape}")
print(f"Testing data shape: {X_test.shape}")
# Out:
# Data shape: (210, 30, 1662)
# Labels shape: (210, 7)
# Training data shape: (199, 30, 1662)
# Testing data shape: (11, 30, 1662)

# %% [markdown]
# ## LSTM Model for Custom ASL Data

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dense, Input
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
# Define input shape (sequence_length, features)
inputs = Input(shape=(30, 1662))

# First LSTM layer
x = LSTM(64, return_sequences=True, activation='relu')(inputs)

# Second LSTM layer
x = LSTM(128, return_sequences=True, activation='relu')(x)

# Third LSTM layer
x = LSTM(64, return_sequences=False, activation='relu')(x)

# Dense layers
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)

# Output layer
outputs = Dense(actions.shape[0], activation='softmax')(x)

# Create model
model = Model(inputs=inputs, outputs=outputs)

# %%
# SIMPLE LSTM MODEL
inputs = Input(shape=(30, 1662))
x = LSTM(32, return_sequences=False, activation='relu')(inputs)
x = Dense(32, activation='relu')(x)
outputs = Dense(actions.shape[0], activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - categorical_accuracy: 0.0800 - loss: 49.1760
# Epoch 2/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.1591 - loss: 33.4323
# Epoch 3/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.1888 - loss: 9.3914
# Epoch 4/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.0973 - loss: 7.4281
# Epoch 5/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.1214 - loss: 5.0369
# Epoch 6/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.1654 - loss: 4.4449
# Epoch 7/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.1096 - loss: 2.7509
# Epoch 8/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.1291 - loss: 2.6340
# Epoch 9/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.1434 - loss: 2.3140
# Epoch 10/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.1880 - loss: 2.3221
# Epoch 11/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.1439 - loss: 2.2160
# Epoch 12/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.1650 - loss: 2.0216
# Epoch 13/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.1630 - loss: 2.1094
# Epoch 14/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.1535 - loss: 2.1198
# Epoch 15/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.1780 - loss: 2.3759
# Epoch 16/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.1218 - loss: 2.6130
# Epoch 17/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.0970 - loss: 2.3246
# Epoch 18/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.1347 - loss: 2.1226
# Epoch 19/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.1201 - loss: 2.1871
# Epoch 20/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.1888 - loss: 2.1386
# Epoch 21/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.1203 - loss: 2.2285
# Epoch 22/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.1588 - loss: 2.0448
# Epoch 23/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.2799 - loss: 1.8844
# Epoch 24/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.1949 - loss: 2.1101
# Epoch 25/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.2472 - loss: 1.9371
# Epoch 26/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.2746 - loss: 2.0306
# Epoch 27/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.3429 - loss: 1.7257
# Epoch 28/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.3359 - loss: 1.7578
# Epoch 29/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.2289 - loss: 2.0838
# Epoch 30/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.2534 - loss: 1.9457
# Epoch 31/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.2946 - loss: 1.7035
# Epoch 32/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.2697 - loss: 1.7174
# Epoch 33/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.2939 - loss: 1.5648
# Epoch 34/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.3669 - loss: 1.4870
# Epoch 35/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.3879 - loss: 1.4914
# Epoch 36/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.2869 - loss: 1.7182
# Epoch 37/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.3184 - loss: 1.9368
# Epoch 38/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.2414 - loss: 1.7070
# Epoch 39/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.2452 - loss: 1.8651
# Epoch 40/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.2984 - loss: 1.7531
# Epoch 41/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.3581 - loss: 1.4779
# Epoch 42/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.3563 - loss: 1.4707
# Epoch 43/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.3535 - loss: 1.7226
# Epoch 44/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4159 - loss: 1.3480
# Epoch 45/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4903 - loss: 1.2530
# Epoch 46/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4144 - loss: 1.3167
# Epoch 47/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.3911 - loss: 1.3303
# Epoch 48/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4252 - loss: 1.3373
# Epoch 49/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4348 - loss: 1.3699
# Epoch 50/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4595 - loss: 1.6854
# Epoch 51/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.3971 - loss: 1.6375
# Epoch 52/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4139 - loss: 1.8710
# Epoch 53/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4134 - loss: 1.5608
# Epoch 54/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4038 - loss: 1.7024
# Epoch 55/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4629 - loss: 1.4093
# Epoch 56/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.3719 - loss: 1.3216
# Epoch 57/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4339 - loss: 1.2557
# Epoch 58/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.3323 - loss: 1.4886
# Epoch 59/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4180 - loss: 1.2779
# Epoch 60/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4156 - loss: 1.3926
# Epoch 61/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4909 - loss: 1.3094
# Epoch 62/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.4176 - loss: 1.2194
# Epoch 63/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4364 - loss: 1.3313
# Epoch 64/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4788 - loss: 1.3857
# Epoch 65/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4003 - loss: 1.3304
# Epoch 66/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.5103 - loss: 1.2352
# Epoch 67/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.3727 - loss: 1.3618
# Epoch 68/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4455 - loss: 1.2136
# Epoch 69/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4779 - loss: 1.2515
# Epoch 70/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4806 - loss: 1.5244
# Epoch 71/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.4190 - loss: 1.3490
# Epoch 72/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4858 - loss: 1.2503
# Epoch 73/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4842 - loss: 1.2371
# Epoch 74/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.3919 - loss: 1.2844
# Epoch 75/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.3871 - loss: 1.3530
# Epoch 76/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4511 - loss: 1.3539
# Epoch 77/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.4364 - loss: 1.2989
# Epoch 78/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5291 - loss: 1.1456
# Epoch 79/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.4811 - loss: 1.1989
# Epoch 80/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4484 - loss: 1.3389
# Epoch 81/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4186 - loss: 1.1619
# Epoch 82/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4511 - loss: 1.4308
# Epoch 83/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4988 - loss: 1.4935
# Epoch 84/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4181 - loss: 1.3531
# Epoch 85/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.3995 - loss: 1.1975
# Epoch 86/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5441 - loss: 1.1716
# Epoch 87/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5044 - loss: 1.0492
# Epoch 88/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.5930 - loss: 1.0087
# Epoch 89/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4742 - loss: 1.1303
# Epoch 90/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4711 - loss: 1.2287
# Epoch 91/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5038 - loss: 1.0400
# Epoch 92/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5510 - loss: 1.0172
# Epoch 93/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4914 - loss: 1.0630
# Epoch 94/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.5382 - loss: 1.0531
# Epoch 95/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.5149 - loss: 1.0846
# Epoch 96/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5932 - loss: 1.0517
# Epoch 97/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.5587 - loss: 1.1528
# Epoch 98/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4910 - loss: 1.1339
# Epoch 99/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4786 - loss: 1.1845
# Epoch 100/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.5441 - loss: 1.1321
# Epoch 101/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5434 - loss: 0.9879
# Epoch 102/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6075 - loss: 0.9710
# Epoch 103/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4625 - loss: 1.4995
# Epoch 104/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4940 - loss: 1.3415
# Epoch 105/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.5601 - loss: 1.1570
# Epoch 106/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4800 - loss: 1.1331
# Epoch 107/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.4645 - loss: 1.0346
# Epoch 108/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4894 - loss: 1.0596
# Epoch 109/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.5395 - loss: 1.0253
# Epoch 110/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6051 - loss: 0.9462
# Epoch 111/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6132 - loss: 0.9202
# Epoch 112/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.5429 - loss: 1.1384
# Epoch 113/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.6077 - loss: 0.9488
# Epoch 114/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5686 - loss: 0.8972
# Epoch 115/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.5712 - loss: 0.9553
# Epoch 116/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6823 - loss: 0.8570
# Epoch 117/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6303 - loss: 0.9338
# Epoch 118/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.5525 - loss: 1.1017
# Epoch 119/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.5613 - loss: 0.9542
# Epoch 120/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.5004 - loss: 1.0751
# Epoch 121/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5642 - loss: 0.8776
# Epoch 122/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5770 - loss: 0.9521
# Epoch 123/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4927 - loss: 1.1168
# Epoch 124/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6032 - loss: 0.9499
# Epoch 125/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4902 - loss: 1.0991
# Epoch 126/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.5652 - loss: 1.0143
# Epoch 127/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.6663 - loss: 0.8129
# Epoch 128/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.6507 - loss: 0.8173
# Epoch 129/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6321 - loss: 0.8570
# Epoch 130/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.6594 - loss: 0.7758
# Epoch 131/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6584 - loss: 0.8075
# Epoch 132/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6067 - loss: 0.8834
# Epoch 133/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5822 - loss: 0.9649
# Epoch 134/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6897 - loss: 0.8444
# Epoch 135/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.7066 - loss: 0.7868
# Epoch 136/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6375 - loss: 0.7813
# Epoch 137/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5931 - loss: 0.9985
# Epoch 138/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5044 - loss: 1.4150
# Epoch 139/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5665 - loss: 0.9145
# Epoch 140/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.5056 - loss: 1.0012
# Epoch 141/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.5461 - loss: 1.0871
# Epoch 142/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6758 - loss: 0.8428
# Epoch 143/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.7133 - loss: 0.7135
# Epoch 144/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6994 - loss: 0.6895
# Epoch 145/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6155 - loss: 0.7725
# Epoch 146/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.7053 - loss: 0.7794
# Epoch 147/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7210 - loss: 0.7332
# Epoch 148/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7344 - loss: 0.7025
# Epoch 149/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7013 - loss: 0.6881
# Epoch 150/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6347 - loss: 0.7636
# Epoch 151/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.7057 - loss: 0.7000
# Epoch 152/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6256 - loss: 0.8243
# Epoch 153/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.5937 - loss: 0.9615
# Epoch 154/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.5125 - loss: 1.2001
# Epoch 155/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.5826 - loss: 0.9414
# Epoch 156/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6215 - loss: 0.8872
# Epoch 157/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.6498 - loss: 0.7474
# Epoch 158/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6050 - loss: 0.8503
# Epoch 159/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.5963 - loss: 0.9173
# Epoch 160/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6436 - loss: 0.9936
# Epoch 161/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5379 - loss: 0.9901
# Epoch 162/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.5965 - loss: 0.8084
# Epoch 163/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6784 - loss: 0.8542
# Epoch 164/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.6863 - loss: 0.8202
# Epoch 165/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6803 - loss: 0.6846
# Epoch 166/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6989 - loss: 0.7226
# Epoch 167/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6199 - loss: 0.8790
# Epoch 168/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7036 - loss: 0.7052
# Epoch 169/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.6458 - loss: 0.7715
# Epoch 170/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7114 - loss: 0.6413
# Epoch 171/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.6733 - loss: 0.7211
# Epoch 172/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.7151 - loss: 0.6422
# Epoch 173/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.7211 - loss: 0.6381
# Epoch 174/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.7399 - loss: 0.6260
# Epoch 175/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7545 - loss: 0.6124
# Epoch 176/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7464 - loss: 0.6377
# Epoch 177/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.7110 - loss: 0.6863
# Epoch 178/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.6663 - loss: 0.7812
# Epoch 179/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7201 - loss: 0.6132
# Epoch 180/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6778 - loss: 0.6677
# Epoch 181/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.6296 - loss: 0.7317
# Epoch 182/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7233 - loss: 0.5937
# Epoch 183/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.7371 - loss: 0.5692
# Epoch 184/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7053 - loss: 0.6446
# Epoch 185/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.6033 - loss: 0.8735
# Epoch 186/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6527 - loss: 0.7026
# Epoch 187/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7174 - loss: 0.6438
# Epoch 188/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7314 - loss: 0.6059
# Epoch 189/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7100 - loss: 0.5392
# Epoch 190/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6661 - loss: 0.7076
# Epoch 191/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7065 - loss: 0.6527
# Epoch 192/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6275 - loss: 0.7315
# Epoch 193/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6731 - loss: 0.5399
# Epoch 194/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.7463 - loss: 0.5760
# Epoch 195/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6370 - loss: 0.7885
# Epoch 196/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.7023 - loss: 0.6320
# Epoch 197/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.6757 - loss: 0.7341
# Epoch 198/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.7001 - loss: 0.6641
# Epoch 199/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.7650 - loss: 0.5690
# Epoch 200/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.6402 - loss: 0.9123
# Epoch 201/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4174 - loss: 1.6723
# Epoch 202/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6239 - loss: 0.9453
# Epoch 203/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7158 - loss: 0.6453
# Epoch 204/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.6554 - loss: 0.8530
# Epoch 205/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6882 - loss: 0.6848
# Epoch 206/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7148 - loss: 0.6191
# Epoch 207/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.7546 - loss: 0.5548
# Epoch 208/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7646 - loss: 0.5614
# Epoch 209/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7860 - loss: 0.5291
# Epoch 210/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7786 - loss: 0.5042
# Epoch 211/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7757 - loss: 0.5049
# Epoch 212/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8060 - loss: 0.4727
# Epoch 213/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8136 - loss: 0.4586
# Epoch 214/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7548 - loss: 0.4977
# Epoch 215/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.7779 - loss: 0.4977
# Epoch 216/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7912 - loss: 0.4517
# Epoch 217/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8187 - loss: 0.4389
# Epoch 218/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.7476 - loss: 0.5065
# Epoch 219/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.7554 - loss: 0.4741
# Epoch 220/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.7534 - loss: 0.4800
# Epoch 221/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.6836 - loss: 0.6824
# Epoch 222/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7436 - loss: 0.6670
# Epoch 223/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6685 - loss: 0.6461
# Epoch 224/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.6888 - loss: 0.6807
# Epoch 225/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6943 - loss: 0.6764
# Epoch 226/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7338 - loss: 0.5798
# Epoch 227/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7868 - loss: 0.4890
# Epoch 228/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.7502 - loss: 0.6183
# Epoch 229/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7399 - loss: 0.6733
# Epoch 230/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7710 - loss: 0.5518
# Epoch 231/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7851 - loss: 0.5101
# Epoch 232/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.7750 - loss: 0.4828
# Epoch 233/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.7881 - loss: 0.4736
# Epoch 234/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7957 - loss: 0.4836
# Epoch 235/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8036 - loss: 0.4820
# Epoch 236/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8029 - loss: 0.4565
# Epoch 237/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7701 - loss: 0.4899
# Epoch 238/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8290 - loss: 0.4456
# Epoch 239/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.7497 - loss: 0.4953
# Epoch 240/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7973 - loss: 0.4160
# Epoch 241/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8604 - loss: 0.4213
# Epoch 242/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8242 - loss: 0.4800
# Epoch 243/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.7253 - loss: 0.5310
# Epoch 244/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7378 - loss: 0.5358
# Epoch 245/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.7455 - loss: 0.5316
# Epoch 246/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8371 - loss: 0.4305
# Epoch 247/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8345 - loss: 0.3994
# Epoch 248/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.7432 - loss: 0.5503
# Epoch 249/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.7817 - loss: 0.5266
# Epoch 250/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8299 - loss: 0.5361
# Epoch 251/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.7416 - loss: 0.6015
# Epoch 252/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8278 - loss: 0.4563
# Epoch 253/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.8045 - loss: 0.4360
# Epoch 254/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.8000 - loss: 0.4321
# Epoch 255/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.8227 - loss: 0.4013
# Epoch 256/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8913 - loss: 0.3827
# Epoch 257/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8362 - loss: 0.4229
# Epoch 258/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9028 - loss: 0.3231
# Epoch 259/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8803 - loss: 0.3820
# Epoch 260/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8351 - loss: 0.3948
# Epoch 261/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8441 - loss: 0.3899
# Epoch 262/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.8305 - loss: 0.3692
# Epoch 263/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7994 - loss: 0.3954
# Epoch 264/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.6745 - loss: 0.8028
# Epoch 265/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.7316 - loss: 0.7893
# Epoch 266/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6946 - loss: 0.8313
# Epoch 267/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.7712 - loss: 0.6647
# Epoch 268/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8363 - loss: 0.4386
# Epoch 269/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8698 - loss: 0.4041
# Epoch 270/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.8025 - loss: 0.4511
# Epoch 271/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8530 - loss: 0.3831
# Epoch 272/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8198 - loss: 0.3755
# Epoch 273/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.7843 - loss: 0.4126
# Epoch 274/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8730 - loss: 0.3672
# Epoch 275/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8595 - loss: 0.3235
# Epoch 276/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8713 - loss: 0.3172
# Epoch 277/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8519 - loss: 0.3639
# Epoch 278/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.8612 - loss: 0.3539
# Epoch 279/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9108 - loss: 0.3385
# Epoch 280/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8668 - loss: 0.3297
# Epoch 281/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8186 - loss: 0.3894
# Epoch 282/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.7580 - loss: 0.4416
# Epoch 283/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.7846 - loss: 0.5247
# Epoch 284/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.7648 - loss: 0.5611
# Epoch 285/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7868 - loss: 0.4929
# Epoch 286/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8829 - loss: 0.3581
# Epoch 287/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.7824 - loss: 0.4639
# Epoch 288/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8019 - loss: 0.4479
# Epoch 289/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.8014 - loss: 0.4076
# Epoch 290/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8634 - loss: 0.3512
# Epoch 291/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9064 - loss: 0.2908
# Epoch 292/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.8766 - loss: 0.3288
# Epoch 293/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8351 - loss: 0.3774
# Epoch 294/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8682 - loss: 0.3093
# Epoch 295/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8595 - loss: 0.3583
# Epoch 296/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8564 - loss: 0.3724
# Epoch 297/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8844 - loss: 0.2852
# Epoch 298/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8846 - loss: 0.3251
# Epoch 299/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.8279 - loss: 0.3628
# Epoch 300/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9190 - loss: 0.2820
# Epoch 301/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8392 - loss: 0.3872
# Epoch 302/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.8956 - loss: 0.3054
# Epoch 303/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8185 - loss: 0.3925
# Epoch 304/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.7544 - loss: 0.4762
# Epoch 305/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.5699 - loss: 1.2459
# Epoch 306/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.6311 - loss: 0.9315
# Epoch 307/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6446 - loss: 1.1382
# Epoch 308/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.6146 - loss: 0.7995
# Epoch 309/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6489 - loss: 0.6996
# Epoch 310/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.7782 - loss: 0.5793
# Epoch 311/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8101 - loss: 0.4847
# Epoch 312/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8525 - loss: 0.4394
# Epoch 313/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.7939 - loss: 0.4539
# Epoch 314/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - categorical_accuracy: 0.8490 - loss: 0.3737
# Epoch 315/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8306 - loss: 0.4528
# Epoch 316/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.8077 - loss: 0.4747
# Epoch 317/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.8506 - loss: 0.3684
# Epoch 318/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.7733 - loss: 0.5053
# Epoch 319/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.8903 - loss: 0.3157
# Epoch 320/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9023 - loss: 0.3054
# Epoch 321/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9062 - loss: 0.3548
# Epoch 322/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.8743 - loss: 0.3895
# Epoch 323/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.8528 - loss: 0.3482
# Epoch 324/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8908 - loss: 0.3044
# Epoch 325/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.8459 - loss: 0.3573
# Epoch 326/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.8732 - loss: 0.3173
# Epoch 327/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.8667 - loss: 0.3319
# Epoch 328/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8941 - loss: 0.3070
# Epoch 329/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.8696 - loss: 0.3337
# Epoch 330/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8799 - loss: 0.3245
# Epoch 331/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8907 - loss: 0.3193
# Epoch 332/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8033 - loss: 0.4292
# Epoch 333/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.7665 - loss: 0.5773
# Epoch 334/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.7178 - loss: 0.6474
# Epoch 335/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.7555 - loss: 0.5334
# Epoch 336/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8269 - loss: 0.4347
# Epoch 337/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.8477 - loss: 0.3727
# Epoch 338/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8252 - loss: 0.4484
# Epoch 339/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.8106 - loss: 0.4808
# Epoch 340/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8556 - loss: 0.3547
# Epoch 341/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9071 - loss: 0.2844
# Epoch 342/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9042 - loss: 0.2979
# Epoch 343/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8704 - loss: 0.3363
# Epoch 344/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8812 - loss: 0.3149
# Epoch 345/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.8918 - loss: 0.3177
# Epoch 346/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.8912 - loss: 0.3031
# Epoch 347/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.8971 - loss: 0.3053
# Epoch 348/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8206 - loss: 0.3779
# Epoch 349/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8868 - loss: 0.2875
# Epoch 350/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8462 - loss: 0.3619
# Epoch 351/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9298 - loss: 0.2257
# Epoch 352/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.8652 - loss: 0.2988
# Epoch 353/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8644 - loss: 0.3681
# Epoch 354/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.8474 - loss: 0.3205
# Epoch 355/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8719 - loss: 0.3955
# Epoch 356/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9118 - loss: 0.3089
# Epoch 357/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9058 - loss: 0.2461
# Epoch 358/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.8756 - loss: 0.2918
# Epoch 359/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9049 - loss: 0.2631
# Epoch 360/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.9038 - loss: 0.2832
# Epoch 361/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9158 - loss: 0.2558
# Epoch 362/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9193 - loss: 0.2349
# Epoch 363/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9100 - loss: 0.2816
# Epoch 364/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.9092 - loss: 0.2939
# Epoch 365/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9410 - loss: 0.2262
# Epoch 366/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.9096 - loss: 0.2144
# Epoch 367/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9451 - loss: 0.2111
# Epoch 368/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8887 - loss: 0.2913
# Epoch 369/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9102 - loss: 0.2595
# Epoch 370/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9142 - loss: 0.2372
# Epoch 371/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9481 - loss: 0.1925
# Epoch 372/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.9256 - loss: 0.2046
# Epoch 373/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9431 - loss: 0.2418
# Epoch 374/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9027 - loss: 0.2318
# Epoch 375/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9561 - loss: 0.1689
# Epoch 376/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9263 - loss: 0.2123
# Epoch 377/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9316 - loss: 0.2224
# Epoch 378/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9311 - loss: 0.2325
# Epoch 379/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.7240 - loss: 1.0314
# Epoch 380/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.4578 - loss: 1.8786
# Epoch 381/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.5603 - loss: 1.8744
# Epoch 382/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.5692 - loss: 1.4189
# Epoch 383/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.5178 - loss: 1.5253
# Epoch 384/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.5587 - loss: 1.3674
# Epoch 385/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.7132 - loss: 0.7068
# Epoch 386/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.7429 - loss: 0.5732
# Epoch 387/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8185 - loss: 0.4968
# Epoch 388/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8348 - loss: 0.4826
# Epoch 389/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.8792 - loss: 0.3908
# Epoch 390/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.8824 - loss: 0.3862
# Epoch 391/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8626 - loss: 0.3579
# Epoch 392/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8832 - loss: 0.3676
# Epoch 393/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.8367 - loss: 0.3838
# Epoch 394/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8334 - loss: 0.4195
# Epoch 395/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9334 - loss: 0.2949
# Epoch 396/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8897 - loss: 0.3560
# Epoch 397/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9037 - loss: 0.3217
# Epoch 398/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9022 - loss: 0.3101
# Epoch 399/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9168 - loss: 0.2880
# Epoch 400/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8603 - loss: 0.3569
# Epoch 401/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9131 - loss: 0.3041
# Epoch 402/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.8881 - loss: 0.3282
# Epoch 403/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9593 - loss: 0.2491
# Epoch 404/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8564 - loss: 0.3147
# Epoch 405/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9111 - loss: 0.2938
# Epoch 406/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8986 - loss: 0.2762
# Epoch 407/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9078 - loss: 0.2957
# Epoch 408/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9155 - loss: 0.2708
# Epoch 409/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8977 - loss: 0.2800
# Epoch 410/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9324 - loss: 0.2502
# Epoch 411/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.8646 - loss: 0.3243
# Epoch 412/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8966 - loss: 0.3036
# Epoch 413/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.8934 - loss: 0.2751
# Epoch 414/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.8971 - loss: 0.2515
# Epoch 415/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9199 - loss: 0.2706
# Epoch 416/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9199 - loss: 0.2666
# Epoch 417/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9516 - loss: 0.2193
# Epoch 418/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9037 - loss: 0.2955
# Epoch 419/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9346 - loss: 0.2107
# Epoch 420/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.8623 - loss: 0.3029
# Epoch 421/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9238 - loss: 0.2563
# Epoch 422/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.9393 - loss: 0.2118
# Epoch 423/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9453 - loss: 0.1843
# Epoch 424/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.8786 - loss: 0.3045
# Epoch 425/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.8703 - loss: 0.3127
# Epoch 426/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.7874 - loss: 0.4935
# Epoch 427/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.7977 - loss: 0.4855
# Epoch 428/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8476 - loss: 0.4125
# Epoch 429/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9114 - loss: 0.2499
# Epoch 430/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9449 - loss: 0.2123
# Epoch 431/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9255 - loss: 0.2343
# Epoch 432/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.9531 - loss: 0.2165
# Epoch 433/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8714 - loss: 0.2995
# Epoch 434/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.8634 - loss: 0.2911
# Epoch 435/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8535 - loss: 0.3092
# Epoch 436/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9010 - loss: 0.2169
# Epoch 437/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9325 - loss: 0.2105
# Epoch 438/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9507 - loss: 0.1877
# Epoch 439/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9308 - loss: 0.2079
# Epoch 440/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.8934 - loss: 0.2700
# Epoch 441/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9132 - loss: 0.2626
# Epoch 442/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.7929 - loss: 0.4290
# Epoch 443/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8842 - loss: 0.2900
# Epoch 444/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9318 - loss: 0.1852
# Epoch 445/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9408 - loss: 0.2109
# Epoch 446/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9448 - loss: 0.1724
# Epoch 447/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9375 - loss: 0.1810
# Epoch 448/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.9466 - loss: 0.1523
# Epoch 449/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.9370 - loss: 0.1905
# Epoch 450/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8975 - loss: 0.2650
# Epoch 451/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.9373 - loss: 0.2189
# Epoch 452/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9413 - loss: 0.1615
# Epoch 453/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.9453 - loss: 0.1907
# Epoch 454/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9315 - loss: 0.1994
# Epoch 455/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9457 - loss: 0.2053
# Epoch 456/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9392 - loss: 0.1964
# Epoch 457/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9274 - loss: 0.2156
# Epoch 458/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9579 - loss: 0.1620
# Epoch 459/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9595 - loss: 0.1587
# Epoch 460/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.9543 - loss: 0.1510
# Epoch 461/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9345 - loss: 0.1931
# Epoch 462/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9389 - loss: 0.1806
# Epoch 463/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9161 - loss: 0.2289
# Epoch 464/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.8430 - loss: 0.3163
# Epoch 465/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9231 - loss: 0.2194
# Epoch 466/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.8847 - loss: 0.2564
# Epoch 467/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8898 - loss: 0.3168
# Epoch 468/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.7620 - loss: 0.6989
# Epoch 469/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.7969 - loss: 0.4349
# Epoch 470/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.8599 - loss: 0.3471
# Epoch 471/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8574 - loss: 0.3942
# Epoch 472/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9210 - loss: 0.2540
# Epoch 473/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9079 - loss: 0.2703
# Epoch 474/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9160 - loss: 0.2426
# Epoch 475/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9152 - loss: 0.2167
# Epoch 476/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9111 - loss: 0.2127
# Epoch 477/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9453 - loss: 0.2184
# Epoch 478/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9056 - loss: 0.2661
# Epoch 479/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9360 - loss: 0.2434
# Epoch 480/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8454 - loss: 0.3770
# Epoch 481/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8912 - loss: 0.2638
# Epoch 482/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8889 - loss: 0.3335
# Epoch 483/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.9121 - loss: 0.2982
# Epoch 484/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9216 - loss: 0.2255
# Epoch 485/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9469 - loss: 0.1701
# Epoch 486/2000
# ...
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9869 - loss: 0.0406
# Epoch 1842/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9558 - loss: 0.0914
# Epoch 1843/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9820 - loss: 0.0368
# Epoch 1844/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9486 - loss: 0.1035
# Epoch 1845/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.8378 - loss: 0.5712
# Epoch 1846/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - categorical_accuracy: 0.9697 - loss: 0.0677
# Epoch 1847/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9749 - loss: 0.0815
# Epoch 1848/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9821 - loss: 0.0422
# Epoch 1849/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9803 - loss: 0.0563
# Epoch 1850/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9743 - loss: 0.0459
# Epoch 1851/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9537 - loss: 0.1066
# Epoch 1852/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9543 - loss: 0.1698
# Epoch 1853/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9756 - loss: 0.0726
# Epoch 1854/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9845 - loss: 0.0762
# Epoch 1855/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9538 - loss: 0.0827
# Epoch 1856/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9854 - loss: 0.0518
# Epoch 1857/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0162
# Epoch 1858/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 1.0000 - loss: 0.0153
# Epoch 1859/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0151
# Epoch 1860/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9892 - loss: 0.0325
# Epoch 1861/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 1.0000 - loss: 0.0110
# Epoch 1862/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 1.0000 - loss: 0.0141
# Epoch 1863/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9931 - loss: 0.0231
# Epoch 1864/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 1.0000 - loss: 0.0108
# Epoch 1865/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0134
# Epoch 1866/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9931 - loss: 0.0208
# Epoch 1867/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9892 - loss: 0.0177
# Epoch 1868/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0142
# Epoch 1869/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0106
# Epoch 1870/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0087
# Epoch 1871/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0075
# Epoch 1872/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 1.0000 - loss: 0.0087
# Epoch 1873/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0082
# Epoch 1874/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0073
# Epoch 1875/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0099
# Epoch 1876/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0097
# Epoch 1877/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 1.0000 - loss: 0.0107
# Epoch 1878/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9973 - loss: 0.0105
# Epoch 1879/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0079
# Epoch 1880/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0082
# Epoch 1881/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 1.0000 - loss: 0.0084
# Epoch 1882/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 1.0000 - loss: 0.0058
# Epoch 1883/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 1.0000 - loss: 0.0056
# Epoch 1884/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 1.0000 - loss: 0.0057
# Epoch 1885/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 1.0000 - loss: 0.0069
# Epoch 1886/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 1.0000 - loss: 0.0056
# Epoch 1887/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0112
# Epoch 1888/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 1.0000 - loss: 0.0049
# Epoch 1889/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0072
# Epoch 1890/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 1.0000 - loss: 0.0047
# Epoch 1891/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9946 - loss: 0.0147
# Epoch 1892/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0126
# Epoch 1893/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 1.0000 - loss: 0.0145
# Epoch 1894/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0080
# Epoch 1895/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 1.0000 - loss: 0.0053
# Epoch 1896/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9963 - loss: 0.0103
# Epoch 1897/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0068
# Epoch 1898/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0095
# Epoch 1899/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 1.0000 - loss: 0.0062
# Epoch 1900/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0097
# Epoch 1901/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 1.0000 - loss: 0.0083
# Epoch 1902/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0077
# Epoch 1903/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 1.0000 - loss: 0.0084
# Epoch 1904/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 1.0000 - loss: 0.0091
# Epoch 1905/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 1.0000 - loss: 0.0071
# Epoch 1906/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - categorical_accuracy: 1.0000 - loss: 0.0056
# Epoch 1907/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 1.0000 - loss: 0.0040
# Epoch 1908/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - categorical_accuracy: 1.0000 - loss: 0.0057
# Epoch 1909/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 1.0000 - loss: 0.0071
# Epoch 1910/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 1.0000 - loss: 0.0064
# Epoch 1911/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 1.0000 - loss: 0.0049
# Epoch 1912/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 1.0000 - loss: 0.0036
# Epoch 1913/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 1.0000 - loss: 0.0066
# Epoch 1914/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 1.0000 - loss: 0.0067
# Epoch 1915/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 1.0000 - loss: 0.0072
# Epoch 1916/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 1.0000 - loss: 0.0041
# Epoch 1917/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 1.0000 - loss: 0.0045
# Epoch 1918/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 1.0000 - loss: 0.0048
# Epoch 1919/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 1.0000 - loss: 0.0052
# Epoch 1920/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 1.0000 - loss: 0.0074
# Epoch 1921/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 1.0000 - loss: 0.0110
# Epoch 1922/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 1.0000 - loss: 0.0101
# Epoch 1923/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9714 - loss: 0.0773
# Epoch 1924/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.8265 - loss: 0.7032
# Epoch 1925/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9099 - loss: 0.3879
# Epoch 1926/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6577 - loss: 1.6133
# Epoch 1927/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.6019 - loss: 1.2128
# Epoch 1928/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.4695 - loss: 1.8990
# Epoch 1929/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6441 - loss: 1.2870
# Epoch 1930/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4560 - loss: 1.5635
# Epoch 1931/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.6346 - loss: 1.4179
# Epoch 1932/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.4535 - loss: 1.3403
# Epoch 1933/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6058 - loss: 0.8056
# Epoch 1934/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.7932 - loss: 0.6893
# Epoch 1935/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8484 - loss: 0.4821
# Epoch 1936/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8734 - loss: 0.3619
# Epoch 1937/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.8805 - loss: 0.3266
# Epoch 1938/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9307 - loss: 0.2906
# Epoch 1939/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8906 - loss: 0.3454
# Epoch 1940/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9339 - loss: 0.2667
# Epoch 1941/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9461 - loss: 0.2594
# Epoch 1942/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9538 - loss: 0.2163
# Epoch 1943/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9050 - loss: 0.3324
# Epoch 1944/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8627 - loss: 0.3395
# Epoch 1945/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8501 - loss: 0.3991
# Epoch 1946/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8245 - loss: 0.5450
# Epoch 1947/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9234 - loss: 0.2646
# Epoch 1948/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9489 - loss: 0.2185
# Epoch 1949/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9542 - loss: 0.1903
# Epoch 1950/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9169 - loss: 0.2313
# Epoch 1951/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9448 - loss: 0.2058
# Epoch 1952/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9438 - loss: 0.1870
# Epoch 1953/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9543 - loss: 0.1726
# Epoch 1954/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9628 - loss: 0.1745
# Epoch 1955/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9139 - loss: 0.2024
# Epoch 1956/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9313 - loss: 0.2210
# Epoch 1957/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9348 - loss: 0.2298
# Epoch 1958/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9433 - loss: 0.1930
# Epoch 1959/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9530 - loss: 0.1678
# Epoch 1960/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9503 - loss: 0.1875
# Epoch 1961/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9679 - loss: 0.1343
# Epoch 1962/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9315 - loss: 0.1887
# Epoch 1963/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8416 - loss: 0.3776
# Epoch 1964/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.8237 - loss: 0.4467
# Epoch 1965/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.8454 - loss: 0.4026
# Epoch 1966/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.8821 - loss: 0.2866
# Epoch 1967/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.8721 - loss: 0.3105
# Epoch 1968/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - categorical_accuracy: 0.8673 - loss: 0.3124
# Epoch 1969/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.8047 - loss: 0.4051
# Epoch 1970/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.7659 - loss: 0.6645
# Epoch 1971/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.8363 - loss: 0.3854
# Epoch 1972/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.7700 - loss: 0.6087
# Epoch 1973/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.8211 - loss: 0.5560
# Epoch 1974/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.8908 - loss: 0.2966
# Epoch 1975/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9335 - loss: 0.2545
# Epoch 1976/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.8439 - loss: 0.4454
# Epoch 1977/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.7150 - loss: 0.8299
# Epoch 1978/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.7709 - loss: 0.6739
# Epoch 1979/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.8220 - loss: 0.4178
# Epoch 1980/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.8601 - loss: 0.3871
# Epoch 1981/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.6075 - loss: 1.1516
# Epoch 1982/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.8050 - loss: 0.4849
# Epoch 1983/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.8758 - loss: 0.2985
# Epoch 1984/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9340 - loss: 0.1819
# Epoch 1985/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9545 - loss: 0.1700
# Epoch 1986/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9650 - loss: 0.1518
# Epoch 1987/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9568 - loss: 0.1222
# Epoch 1988/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9728 - loss: 0.1079
# Epoch 1989/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9625 - loss: 0.1193
# Epoch 1990/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9670 - loss: 0.1129
# Epoch 1991/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9898 - loss: 0.0935
# Epoch 1992/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9594 - loss: 0.1109
# Epoch 1993/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9541 - loss: 0.1469
# Epoch 1994/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9666 - loss: 0.1308
# Epoch 1995/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9545 - loss: 0.1351
# Epoch 1996/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9669 - loss: 0.1250
# Epoch 1997/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9791 - loss: 0.1004
# Epoch 1998/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9750 - loss: 0.1151
# Epoch 1999/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9250 - loss: 0.1385
# Epoch 2000/2000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.9910 - loss: 0.0876

# %%
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 30, 1662)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 32)             │       216,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 654,743 (2.50 MB)
#  Trainable params: 218,247 (852.53 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 436,496 (1.67 MB)

# %% [markdown]
# ## Save Weights

# %%
model.save('Models/01_lstm_model.h5')
model.save_weights('Models/01_model.weights.h5');
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf
model = tf.keras.models.load_model('Models/01_lstm_model.h5')
model.load_weights('Models/01_model.weights.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /Users/alexandershin/school/year4/seniorproj/ASL_Glasses/venv/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 16 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# ## Evaluate Using Confusion Matrix

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[10,  0],
#         [ 0,  1]],
#
#        [[ 8,  1],
#         [ 0,  2]],
#
#        [[ 9,  0],
#         [ 1,  1]],
#
#        [[ 9,  1],
#         [ 0,  1]],
#
#        [[ 9,  0],
#         [ 1,  1]],
#
#        [[ 8,  0],
#         [ 0,  3]]])

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.8181818181818182

# %% [markdown]
# # Realtime Test

# %%
from scipy import stats

# %%
colors = [
    (245, 117, 16),  # Orange
    (117, 245, 16),  # Green
    (16, 117, 245),  # Blue
    (255, 0, 0),     # Red
    (0, 255, 255),   # Cyan
    (255, 0, 255),   # Magenta
    (0, 0, 0)        # Black
]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = process_mp_frames(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints_comprehensive(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# I0000 00:00:1744310901.506077 16339090 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M1 Pro
# W0000 00:00:1744310901.593049 16609793 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744310901.608987 16609793 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744310901.611712 16609791 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744310901.611842 16609793 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744310901.615634 16609798 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744310901.620990 16609800 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744310901.623878 16609796 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1744310901.629186 16609791 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# yes
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# no

# %% [markdown]
# ## MVP

# %%
from collections import deque

def prob_viz(res, actions, input_frame, colors):
    """
    Visualize probabilities for each action
    """
    output_frame = input_frame.copy()
    
    # Draw rectangles and text for each action
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0, 60 + num * 40), (int(prob * 100), 90 + num * 40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85 + num * 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
    
    return output_frame

def real_time_asl_detection():
    # Define actions - must match the ones used for training
    actions = np.array(['hello', 'thanks', 'iloveyou', 'yes', 'no', 'please', 'sorry'])
    
    # Define colors for visualization
    colors = [(245, 117, 16), (117, 245, 16), (16, 117, 245), (255, 0, 0), (0, 255, 0), (0, 0, 255), (200, 200, 200)]
    
    # Load the model
    model_path = 'Models/final_model.h5'
    if not os.path.exists(model_path):
        print(f"Error: Model not found at {model_path}")
        return
    
    model = tf.keras.models.load_model(model_path)
    print(f"Model loaded from {model_path}")
    
    # Initialize sequence buffer
    sequence = deque(maxlen=30)
    
    # Initialize prediction variables
    sentence = []
    threshold = 0.8  # Confidence threshold
    last_prediction_time = 0
    cooldown = 2.0  # Seconds between predictions
    
    # Initialize webcam
    cap = cv2.VideoCapture(0)
    
    # Initialize MediaPipe Holistic
    with mp_holistic.Holistic(
        min_detection_confidence=0.5,
        min_tracking_confidence=0.5
    ) as holistic:
        while cap.isOpened():
            # Read frame
            ret, frame = cap.read()
            if not ret:
                print("Failed to grab frame")
                break
                
            # Make frame smaller for faster processing
            frame = cv2.resize(frame, (640, 480))
            
            # Process frame
            image, results = process_mp_frames(frame, holistic)
            
            # Draw landmarks
            draw_landmarks(image, results)
            
            # Extract keypoints
            keypoints = extract_keypoints_comprehensive(results)
            
            # Add to sequence
            sequence.append(keypoints)
            
            # Make prediction when buffer is full
            if len(sequence) == 30:
                # Prepare for model
                input_data = np.expand_dims(np.array(sequence), axis=0)
                
                # Get prediction
                res = model.predict(input_data, verbose=0)[0]
                
                # Get class with highest probability
                predicted_class_idx = np.argmax(res)
                predicted_class = actions[predicted_class_idx]
                confidence = res[predicted_class_idx]
                
                # Only add prediction if confidence is high enough and cooldown has passed
                current_time = time.time()
                if confidence > threshold and (current_time - last_prediction_time) > cooldown:
                    # Add prediction to sentence if it's different from the last one
                    if len(sentence) == 0 or predicted_class != sentence[-1]:
                        sentence.append(predicted_class)
                        # Limit sentence length
                        if len(sentence) > 5:
                            sentence = sentence[-5:]
                    
                    last_prediction_time = current_time
                
                # Visualize probabilities
                image = prob_viz(res, actions, image, colors)
            
            # Show prediction on frame
            cv2.rectangle(image, (0, 0), (640, 40), (245, 117, 16), -1)
            
            # Show current detected sign
            if len(sentence) > 0:
                cv2.putText(image, f"Detected: {sentence[-1]}", (3, 30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Show full sentence
            if len(sentence) > 1:
                # Position at bottom of frame
                sentence_text = ' '.join(sentence)
                text_size = cv2.getTextSize(sentence_text, cv2.FONT_HERSHEY_SIMPLEX, 1, 2)[0]
                
                # Create transparent overlay for text
                overlay = image.copy()
                cv2.rectangle(overlay, (0, image.shape[0] - 50), (image.shape[1], image.shape[0]), (0, 0, 0), -1)
                alpha = 0.7
                image = cv2.addWeighted(overlay, alpha, image, 1 - alpha, 0)
                
                # Draw text
                cv2.putText(image, sentence_text, (10, image.shape[0] - 20), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Show frame
            cv2.imshow('ASL Detection', image)
            
            # Break on 'q' key
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
    
    # Release resources
    cap.release()
    cv2.destroyAllWindows()

# %%
real_time_asl_detection()

# %% [markdown]
# ## Dataset Collection and Processing Pipeline for Pre-built Dataset

# %%
WLASL_PATH = "WLASL_DATA"
VIDEOS_PATH = os.path.join(WLASL_PATH, "videos")
JSON_PATH = os.path.join(WLASL_PATH, "WLASL_v0.3.json")
OUTPUT_PATH = "WLASL_Processed"

# Create Output directory
os.makedirs(OUTPUT_PATH, exist_ok=True)

# %% [markdown]
# **Verify Dataset Structure**

# %%
print("WLASL folder contents:")
print(os.listdir(WLASL_PATH))

# If there's a JSON file, check its structure
json_path = os.path.join(WLASL_PATH, "WLASL_v0.3.json")
if os.path.exists(json_path):
    with open(json_path, 'r') as f:
        data = json.load(f)
    print(f"\nJSON file contains data for {len(data)} signs")
    print(f"Example of first sign: {data[0]['gloss']}")

# %% [markdown]
# **Process Videos**

# %%
def process_video(video_path, output_dir, max_frames=30):
    """Process a single video file and extract landmarks"""
    # Create Output Directory
    os.makedirs(output_dir, exist_ok=True)

    # open video
    cap = cv2.VideoCapture(video_path)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate frame sampling rate
    if frame_count <= max_frames:
        # Use all frames is video is short
        frame_indices = list(range(frame_count))
    else:
        # Sample frames evenly if video is long
        frame_indices = np.linspace(0, frame_count-1, max_frames, dtype=int)

    # Initialize MediaPipe
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        # Process Frames
        for frame_idx, i in enumerate(frame_indices):
            # Set frame position
            cap.set(cv2.CAP_PROP_POS_FRAMES, i)
            success, frame = cap.read()

            if not success:
                print(f"Could not read frame {i} from {video_path}")
                continue
                
            # Process image
            image, results = process_mp_frames(frame, holistic)
            
            # Extract and savve keypoints
            keypoints_vector = extract_keypoints_comprehensive(results)
            npy_path = os.path.join(output_dir, str(frame_idx))
            np.save(npy_path, keypoints_vector)

    cap.release()
    return len(frame_indices)

# %%
def process_wlasl_dataset(max_signs=None, max_videos_per_sign=30):
    """Process the WLASL dataset"""
    # Load WLASL metadata
    with open(JSON_PATH, 'r') as f:
        wlasl_data = json.load(f)

    # Limit number of signs if specified
    if max_signs:
        wlasl_data = wlasl_data[:max_signs]

    # list to store sign info
    processed_signs = []

    # Create sign to ID mapping
    sign_map = {sign_data['gloss']: idx for idx, sign_data in enumerate(wlasl_data)}

    # Save sign map for later use
    with open(os.path.join(OUTPUT_PATH, 'sign_map.json'), 'w') as f:
        json.dump(sign_map, f, indent=2)

    # Process each sign
    for sign_idx, sign_data in enumerate(tqdm(wlasl_data, desc="Processing signs")):
        sign_name = sign_data['gloss']
        sign_id = sign_idx  # Use index as class ID
        
        # Create directory for this sign
        sign_dir = os.path.join(OUTPUT_PATH, sign_name)
        os.makedirs(sign_dir, exist_ok=True)

        # Process videos for this sign
        videos_processed = 0
        
        for i, instance in enumerate(sign_data['instances']):
            if videos_processed >= max_videos_per_sign:
                break
                
            video_id = instance['video_id']
            video_path = os.path.join(VIDEOS_PATH, f"{video_id}.mp4")
            
            # Check if video exists
            if not os.path.exists(video_path):
                print(f"Video not found: {video_path}")
                continue
            
            # Process video
            output_dir = os.path.join(sign_dir, str(videos_processed))
            frames_processed = process_video(video_path, output_dir)
            
            if frames_processed > 0:
                videos_processed += 1
                print(f"Processed {sign_name} video {videos_processed}/{max_videos_per_sign}")
        
        # Add to processed signs list
        processed_signs.append({
            'name': sign_name,
            'id': sign_id,
            'videos_processed': videos_processed
        })
        
        print(f"Completed sign: {sign_name} - {videos_processed} videos processed")
    
    # Save processed sign information
    with open(os.path.join(OUTPUT_PATH, 'processed_signs.json'), 'w') as f:
        json.dump(processed_signs, f, indent=2)
    
    return processed_signs

# %% [markdown]
# **Processing Dataset in parallel**

# %% [markdown]
# *The parallel data processing is put here just to view, but this code was copied into a seperate python script bceause Jupyter Notebook doesn't really support multiprocessing*

# %%
import multiprocessing
from functools import partial

# %%
def process_video_parallel(video_info, output_base_dir, max_frames=30):
    """Process a single video file and extract landmarks"""
    sign_name, video_idx, video_id = video_info
    
    # Create output directory for this video
    output_dir = os.path.join(output_base_dir, sign_name, str(video_idx))
    os.makedirs(output_dir, exist_ok=True)
    
    # Form video path
    video_path = os.path.join("WLASL_DATA", "videos", f"{video_id}.mp4")
    
    # Check if video exists
    if not os.path.exists(video_path):
        print(f"Video not found: {video_path}")
        return False
    
    try:
        # Open video
        cap = cv2.VideoCapture(video_path)
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        
        # Calculate frame sampling rate
        if frame_count <= max_frames:
            frame_indices = list(range(frame_count))
        else:
            frame_indices = np.linspace(0, frame_count-1, max_frames, dtype=int)
        
        # Initialize MediaPipe - create a new instance for each process
        with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
            # Process Frames
            for frame_idx, i in enumerate(frame_indices):
                # Set frame position
                cap.set(cv2.CAP_PROP_POS_FRAMES, i)
                success, frame = cap.read()
                if not success:
                    continue
                    
                # Process image
                results = process_mp_frames(frame, holistic)
                
                # Extract and save keypoints
                keypoints_vector = extract_keypoints_comprehensive(results)
                npy_path = os.path.join(output_dir, f"{frame_idx}.npy")
                np.save(npy_path, keypoints_vector)
        
        cap.release()
        return True
    except Exception as e:
        print(f"Error processing {video_path}: {e}")
        return False

# %%
def process_wlasl_dataset_parallel(max_signs=None, max_videos_per_sign=30, num_processes=None):
    """Process WLASL Dataset using parallel processing"""
    # If num processes isn't specified using all the available cores - 1
    if num_processes is None:
        num_processes = max(1, multiprocessing.cpu_count() - 1)

    # Load WLASL metadata
    with open(os.path.join("WLASL_DATA", "WLASL_v0.3.json"), 'r') as f:
        wlasl_data = json.load(f)
    
    # Limit number of signs if specified
    if max_signs:
        wlasl_data = wlasl_data[:max_signs]

    # Create sign to ID mapping
    sign_map = {sign_data['gloss']: idx for idx, sign_data in enumerate(wlasl_data)}
    
    # Output directory
    output_path = "WLASL_Processed"
    os.makedirs(output_path, exist_ok=True)
    
    # Save sign map for later use
    with open(os.path.join(output_path, 'sign_map.json'), 'w') as f:
        json.dump(sign_map, f, indent=2)
    
    # Prepare list of videos to process
    videos_to_process = []
    for sign_idx, sign_data in enumerate(wlasl_data):
        sign_name = sign_data['gloss']
        
        # Create directory for this sign
        sign_dir = os.path.join(output_path, sign_name)
        os.makedirs(sign_dir, exist_ok=True)
        
        # Add videos for this sign to process list (limited by max_videos_per_sign)
        for video_idx, instance in enumerate(sign_data['instances'][:max_videos_per_sign]):
            video_id = instance['video_id']
            videos_to_process.append((sign_name, video_idx, video_id))
            
    # Create a partial function with fixed arguments
    process_func = partial(process_video_parallel, output_base_dir=output_path)
    
    # Process videos in parallel
    print(f"Processing {len(videos_to_process)} videos using {num_processes} processes...")
    
    # Create a multiprocessing pool
    with multiprocessing.Pool(processes=num_processes) as pool:
        # Process videos and track progress with tqdm
        results = list(tqdm(
            pool.imap(process_func, videos_to_process),
            total=len(videos_to_process),
            desc="Processing videos"
        ))
    
    # Count processed videos per sign
    processed_counts = {}
    for sign_name, _, _ in videos_to_process:
        if sign_name not in processed_counts:
            processed_counts[sign_name] = 0
        processed_counts[sign_name] += 1
    
    # Create processed sign information
    processed_signs = [
        {
            'name': sign_data['gloss'],
            'id': idx,
            'videos_processed': processed_counts.get(sign_data['gloss'], 0)
        }
        for idx, sign_data in enumerate(wlasl_data)
    ]
    
    # Save processed sign information
    with open(os.path.join(output_path, 'processed_signs.json'), 'w') as f:
        json.dump(processed_signs, f, indent=2)
    
    print(f"Dataset processing complete. Processed {sum(results)} videos successfully.")
    return processed_signs

# %%
# Testing with small subset
process_wlasl_dataset(max_signs=10, max_videos_per_sign=10)

# %%
# Process Entire Dataset
# process_wlasl_dataset()

# %%
# Process Entire WLASL Dataset in Parallel
# process_wlasl_dataset_parallel(num_processes=3)

# %% [markdown]
# ## Basic LSTM Model using WLASL Dataset

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

np.random.seed(42)
tf.random.set_seed(42)

def load_wlasl_data(processed_data_path, sequence_length=30):
    """Load Processed WLASL data into train/test sets"""
    # Load sign mapping
    with open(os.path.join(processed_data_path, 'sign_map.json'), 'r') as f:
        sign_map = json.load(f)
    
    # Get list of sign directories
    sign_dirs = [d for d in os.listdir(processed_data_path) 
                 if os.path.isdir(os.path.join(processed_data_path, d)) and d in sign_map]
    
    # Prepare data containers
    X = []  # Features
    y = []  # Labels

    # Process each sign
    for sign_name in sign_dirs:
        sign_dir = os.path.join(processed_data_path, sign_name)
        
        # Get video instances for this sign
        video_dirs = [d for d in os.listdir(sign_dir) 
                     if os.path.isdir(os.path.join(sign_dir, d))]
        
        # Process each video instance
        for video_idx in video_dirs:
            video_dir = os.path.join(sign_dir, video_idx)
            
            # Get frame files
            frame_files = [f for f in os.listdir(video_dir) if f.endswith('.npy')]
            frame_files.sort(key=lambda x: int(x.split('.')[0]))  # Sort by frame index
            
            # Check if we have enough frames
            if len(frame_files) < 1:
                continue
            
            # Load sequence
            sequence = []
            for frame_file in frame_files:
                frame_path = os.path.join(video_dir, frame_file)
                frame_data = np.load(frame_path)
                sequence.append(frame_data)
            
            # Pad or truncate to sequence_length
            if len(sequence) > sequence_length:
                sequence = sequence[:sequence_length]
            elif len(sequence) < sequence_length:
                # Pad with zeros
                padding = [np.zeros_like(sequence[0]) for _ in range(sequence_length - len(sequence))]
                sequence.extend(padding)
            
            # Add to dataset
            X.append(np.array(sequence))
            y.append(sign_map[sign_name])
    
    # Convert to numpy arrays
    X = np.array(X)
    y = np.array(y)
    
    # One-hot encode labels
    num_classes = len(sign_map)
    y_encoded = to_categorical(y, num_classes=num_classes)
    
    # Split data
    X_train, X_test, y_train, y_test = train_test_split(
        X, y_encoded, test_size=0.2, random_state=42, stratify=y
    )
    
    print(f"Loaded {len(X)} sequences across {len(sign_map)} signs")
    print(f"Features shape: {X.shape}")
    print(f"Labels shape: {y_encoded.shape}")
    print(f"Training set: {X_train.shape[0]} sequences")
    print(f"Test set: {X_test.shape[0]} sequences")
    
    return X_train, X_test, y_train, y_test, sign_map

# %%
def create_model(input_shape, num_classes):
    """Basic LSTM model for ASL Translation"""
    model = Sequential()
    
    # LSTM layers
    model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=input_shape))
    model.add(LSTM(128, return_sequences=True, activation='relu'))
    model.add(LSTM(64, return_sequences=False, activation='relu'))
    
    # Dense layers
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    
    # Output layer
    model.add(Dense(num_classes, activation='softmax'))

    # # Create Adam optimizer with a lower learning rate
    # optimizer = Adam(learning_rate=0.0001)  # Default is 0.001, so this is 10x smaller
    
    # Compile model
    model.compile(
        optimizer='Adam',
        loss='categorical_crossentropy',
        metrics=['categorical_accuracy']
    )
    
    return model

# %%
def train_model(model, X_train, y_train, X_test, y_test, epochs=100, batch_size=32):
    # Setup TensorBoard logging
    log_dir = os.path.join('Logs')
    os.makedirs(log_dir, exist_ok=True)
    tb_callback = TensorBoard(log_dir=log_dir)
    
    # Setup model checkpoint to save best model
    checkpoint_path = os.path.join('Models', 'checkpoint.h5')
    os.makedirs('Models', exist_ok=True)
    cp_callback = ModelCheckpoint(
        checkpoint_path, 
        monitor='val_categorical_accuracy',
        save_best_only=True,
        verbose=1
    )
    
    # # Early stopping to prevent overfitting
    # es_callback = EarlyStopping(
    #     monitor='val_categorical_accuracy',
    #     patience=10,
    #     verbose=1,
    #     restore_best_weights=True
    # )
    
    # Train model
    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test, y_test),
        callbacks=[tb_callback, cp_callback]
    )
    
    return history

# %%
processed_data_path = "WLASL_Processed"
X_train, X_test, y_train, y_test, sign_map = load_wlasl_data(processed_data_path)
# Get input shape and number of classes
input_shape = (X_train.shape[1], X_train.shape[2])  # (sequence_length, num_features)
num_classes = y_train.shape[1]

# Create model
model = create_model(input_shape, num_classes)

# Print model summary
model.summary()

# Train model
history = train_model(model, X_train, y_train, X_test, y_test, epochs=100)

# %%
def plot_training_history(history):
    """
    Plot the training history
    
    Args:
        history: Training history returned by model.fit()
    """
    # Create figure with 2 subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
    
    # Plot accuracy
    ax1.plot(history.history['categorical_accuracy'])
    ax1.plot(history.history['val_categorical_accuracy'])
    ax1.set_title('Model Accuracy')
    ax1.set_ylabel('Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.legend(['Train', 'Validation'], loc='lower right')
    ax1.grid(True, alpha=0.3)
    
    # Plot loss
    ax2.plot(history.history['loss'])
    ax2.plot(history.history['val_loss'])
    ax2.set_title('Model Loss')
    ax2.set_ylabel('Loss')
    ax2.set_xlabel('Epoch')
    ax2.legend(['Train', 'Validation'], loc='upper right')
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

def evaluate_model(model, X_test, y_test, sign_map):
    """
    Evaluate the model performance
    
    Args:
        model: Trained Keras model
        X_test, y_test: Test data
        sign_map: Mapping from sign names to indices
    """
    # Get predictions
    y_pred = model.predict(X_test)
    
    # Convert from one-hot encoded to class indices
    y_true = np.argmax(y_test, axis=1)
    y_pred = np.argmax(y_pred, axis=1)
    
    # Calculate accuracy
    accuracy = np.sum(y_true == y_pred) / len(y_true)
    print(f"Test accuracy: {accuracy:.4f}")
    
    # Get inverse mapping (index to sign name)
    idx_to_sign = {v: k for k, v in sign_map.items()}
    
    # Show some example predictions
    print("\nExample predictions:")
    for i in range(min(5, len(y_true))):
        true_sign = idx_to_sign[y_true[i]]
        pred_sign = idx_to_sign[y_pred[i]]
        print(f"True: {true_sign}, Predicted: {pred_sign}")

# %%
# Plot training history
plot_training_history(history)

# Evaluate model
evaluate_model(model, X_test, y_test, sign_map)
